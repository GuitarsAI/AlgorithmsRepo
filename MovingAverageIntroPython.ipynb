# %% [markdown]
# # Moving Average Filter Javascript
# <p align="left">
# <img src="./img/businesscard.jpg" width="500px" alt="Business Card" align="left" >
# </p>
# <br>
#
# [www.rptecnologias.com](http://www.rptecnologias.com)
# <br>
# guitars.ai@rptecnologias.com

# %% [markdown]
# ## Python: Imports and Configuration

# %%
# General Imports
import numpy as np
import scipy.signal as signal

#Display ang Plots
# %matplotlib notebook
import matplotlib.pyplot as plt
from IPython.core.display import HTML, display

# %%
# Function to Display a Website
def show_web(url):
    html_code='<center><iframe src="%s" width="800" height="600" frameborder="0" marginheight="0" marginwidth="0">Loading...</iframe></center>' \
		% (url)
    display(HTML(html_code))

# %%
show_web("https://en.wikipedia.org/wiki/Finite_impulse_response#Moving_average_example")
# Out:
# <center><iframe src="https://en.wikipedia.org/wiki/Finite_impulse_response#Moving_average_example" width="800" height="600" frameborder="0" marginheight="0" marginwidth="0">Loading...</iframe></center>

# %% [markdown]
# ## Moving Average Filter Function

# %%
# Moving Average Impulse Response
def hMovingAverage(taps):
    return (1/taps)*np.ones(taps)

# %%
h=hMovingAverage(11)

# %% [markdown]
# ## Convolution 1D with Delay Compensation

# %%
# Define Convolution1D
def Convolution1D(f,g, delay=True):
    y=np.zeros(f.size+g.size-1)
    for n in range(f.size):
        for m in range(g.size):
                y[n+m]+=f[n]*g[m]
    if delay:
        return y[round((g.size-1)/2):-(g.size-1)]
    else:
        return y

# %% [markdown]
# ## Define Signals

# %%
x=np.linspace(0,100,100)
noise=np.random.uniform(-1,1,100)
x_noise = x+4*noise
x_noise_filtered=Convolution1D(x_noise,h)

# %% [markdown]
# ## Plot

# %%
plt.figure(figsize=(8,6))
plt.title("Moving Average Filter")
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x, label='Ramp')
plt.plot(x_noise, 'g.', label='Ramp+Noise')
plt.plot(x_noise_filtered, 'r--', label='Filtered Ramp+Noise (Delay Compensated)')
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="800">
